# %%
# import packages
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
from collections import Counter

from sklearn.model_selection import train_test_split, KFold, cross_val_score, GridSearchCV
import statsmodels.api as sm

from sklearn.preprocessing import PolynomialFeatures, StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier, AdaBoostClassifier, GradientBoostingClassifier
from sklearn.metrics import confusion_matrix, plot_confusion_matrix, accuracy_score, recall_score, precision_score, f1_score, plot_roc_curve, roc_auc_score
from sklearn.pipeline import Pipeline
from imblearn.over_sampling import SMOTE
from sklearn.neighbors import KernelDensity

sns.set_style('white')
pd.set_option('display.max_columns', None)

import warnings
warnings.filterwarnings('ignore')

# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

# %% [markdown]
# ## Data Import

# %%
weather = pd.read_csv('./output/weather_cleaned.csv')
spray = pd.read_csv('./output/spray_cleaned.csv')
train = pd.read_csv('./output/train_cleaned.csv')
test = pd.read_csv('./output/test_cleaned.csv')

# %%
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2944 entries, 0 to 2943
# Data columns (total 20 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Station      2944 non-null   int64
#  1   Date         2944 non-null   object
#  2   Tmax         2944 non-null   int64
#  3   Tmin         2944 non-null   int64
#  4   Tavg         2944 non-null   int64
#  5   Depart       2944 non-null   int64
#  6   DewPoint     2944 non-null   int64
#  7   WetBulb      2944 non-null   int64
#  8   Heat         2944 non-null   int64
#  9   Cool         2944 non-null   int64
#  10  Sunrise      2944 non-null   int64
#  11  Sunset       2944 non-null   int64
#  12  CodeSum      2944 non-null   object
#  13  PrecipBool   2944 non-null   int64
#  14  PrecipTotal  2944 non-null   float64
#  15  StnPressure  2944 non-null   float64
#  16  SeaLevel     2944 non-null   float64
#  17  ResultSpeed  2944 non-null   float64
#  18  ResultDir    2944 non-null   int64
#  19  AvgSpeed     2944 non-null   float64
# dtypes: float64(5), int64(13), object(2)
# memory usage: 460.1+ KB

# %%
# Convert date to datetime.
weather['Date'] = pd.to_datetime(weather['Date'])

# %%
spray.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14294 entries, 0 to 14293
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        14294 non-null  object
#  1   Latitude    14294 non-null  float64
#  2   Longitude   14294 non-null  float64
#  3   Month       14294 non-null  int64
#  4   Week        14294 non-null  int64
#  5   Year        14294 non-null  int64
#  6   Year Month  14294 non-null  object
# dtypes: float64(2), int64(3), object(2)
# memory usage: 781.8+ KB

# %%
# Convert date to datetime.
spray['Date'] = pd.to_datetime(spray['Date'])

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9693 entries, 0 to 9692
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Date                    9693 non-null   object
#  1   Address                 9693 non-null   object
#  2   Species                 9693 non-null   object
#  3   Block                   9693 non-null   int64
#  4   Street                  9693 non-null   object
#  5   Trap                    9693 non-null   object
#  6   AddressNumberAndStreet  9693 non-null   object
#  7   Latitude                9693 non-null   float64
#  8   Longitude               9693 non-null   float64
#  9   AddressAccuracy         9693 non-null   int64
#  10  NumMosquitos            9693 non-null   int64
#  11  WnvPresent              9693 non-null   int64
#  12  Month                   9693 non-null   int64
#  13  Week                    9693 non-null   int64
#  14  Year                    9693 non-null   int64
#  15  Year Month              9693 non-null   object
#  16  LatLong                 9693 non-null   object
#  17  Coord                   9693 non-null   object
#  18  Nearest_Station         9693 non-null   int64
# dtypes: float64(2), int64(8), object(9)
# memory usage: 1.4+ MB

# %%
train['Date'] = pd.to_datetime(train['Date'])

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 116293 entries, 0 to 116292
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Id                      116293 non-null  int64
#  1   Date                    116293 non-null  object
#  2   Address                 116293 non-null  object
#  3   Species                 116293 non-null  object
#  4   Block                   116293 non-null  int64
#  5   Street                  116293 non-null  object
#  6   Trap                    116293 non-null  object
#  7   AddressNumberAndStreet  116293 non-null  object
#  8   Latitude                116293 non-null  float64
#  9   Longitude               116293 non-null  float64
#  10  AddressAccuracy         116293 non-null  int64
#  11  Month                   116293 non-null  int64
#  12  Week                    116293 non-null  int64
#  13  Year                    116293 non-null  int64
#  14  Year Month              116293 non-null  object
#  15  LatLong                 116293 non-null  object
#  16  Coord                   116293 non-null  object
#  17  Nearest_Station         116293 non-null  int64
# dtypes: float64(2), int64(7), object(9)
# memory usage: 16.0+ MB

# %%
# Convert date to datetime.
test['Date'] = pd.to_datetime(test['Date'])

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# ### Weather -- Sunhour Feature

# %%
# change datatypes of Sunrise and Sunset values 
weather['Sunrise'] = weather['Sunrise'].apply(str)
weather['Sunset'] = weather['Sunset'].apply(str)

# %%
# convert Sunrise and Sunset values to datetime
sunrise_time = []
for val in weather['Sunrise']:
    date_val = datetime.datetime.strptime(val, '%H%M')
    sunrise_time.append(date_val.hour + date_val.minute/60)

sunset_time = []
for val in weather['Sunset']:
    try:
        date_val = datetime.datetime.strptime(val, '%H%M')
        sunset_time.append(date_val.hour + date_val.minute/60)
    except:
        date_val = datetime.datetime.strptime(val.replace('60', '59'), '%H%M')
        sunset_time.append(date_val.hour + date_val.minute/60)

# convert values to hours from midnight
weather['Sunrise'] = sunrise_time
weather['Sunset'] = sunset_time

# %%
# create new column to store sunhours
weather['SunHours'] = weather['Sunset'] - weather['Sunrise']

# drop Sunrise and Sunset columns
weather.drop(columns=['Sunrise', 'Sunset'], inplace=True)

# %% [markdown]
# ### Weather -- Codesum Feature

# %% [markdown]
# Only days with weather condition will be recorded in the dataset. Hence, empty strings in this column actually means that it is a weather-wise uneventful day. We can replace all empty string with '0' to indicate that.
#
# Specifically, we want to create dummy variables - Rain, Snow, Windy and Misty - as follows:
#
# Rain = 1 if CodeSum contains ['TS', 'RA', 'DZ', 'SH'] else = 0
#
# Snow = 1 if CodeSum contains ['SN', 'SG', 'GS', 'PL', 'IC', 'DR', 'BC', 'GR'] else = 0
#
# Windy = 1 if CodeSum contains ['SQ', 'DS', 'SS', 'PO', 'BL'] else = 0
#
# Misty = 1 if CodeSum contains ['BR', 'HZ', 'FG', 'FU'] else = 0

# %%
weather["CodeSum"].unique()
# Out:
# array([' ', 'BR', 'BR HZ', 'HZ', 'RA', 'RA BR', 'TSRA RA BR', 'RA VCTS',
#        'TSRA RA', 'RA HZ', 'TSRA RA BR HZ', 'TSRA BR HZ', 'RA BR HZ VCTS',
#        'TSRA RA HZ', 'TSRA BR HZ VCTS', 'TSRA', 'TSRA BR HZ FU',
#        'TSRA RA HZ FU', 'BR HZ FU', 'TSRA RA VCTS', 'HZ VCTS', 'TSRA HZ',
#        'VCTS', 'RA BR VCTS', 'TSRA RA BR VCTS', 'TS TSRA RA BR HZ VCTS',
#        'DZ BR', 'TS TSRA RA BR HZ', 'TS TSRA BR HZ', 'RA BR HZ',
#        'TSRA RA DZ BR HZ', 'TS TSRA RA BR', 'TS RA BR', 'TS TSRA RA',
#        'TS TSRA RA BR VCTS', 'TS TSRA BR', 'TS RA', 'RA BCFG BR',
#        'TSRA BR', 'RA DZ FG+ BCFG BR', 'RA FG+ MIFG BR', 'RA DZ',
#        'RA DZ BR', 'TS TSRA RA HZ', 'TSRA RA FG+ FG BR',
#        'TSRA DZ FG+ FG BR HZ', 'TS BR', 'RA BR SQ', 'TS TSRA',
#        'TSRA RA BR HZ VCTS', 'BR VCTS', 'TS', 'FG+ BR HZ', 'RA SN',
#        'TSRA RA DZ BR', 'DZ BR HZ', 'RA BR FU', 'TS BR HZ', 'DZ',
#        'FG+ BR', 'FG+ FG BR', 'FG+ MIFG BR', 'TSRA RA FG BR',
#        'TSRA FG+ BR', 'RA DZ BR HZ', 'RA DZ SN', 'FG+ FG BR HZ',
#        'TS TSRA RA FG BR', 'BR HZ VCFG', 'TS RA FG+ FG BR',
#        'TSRA RA FG+ BR', 'RA DZ FG+ FG BR', 'TS TSRA RA VCTS', 'FU',
#        'TS TSRA VCFG', 'TS TSRA HZ', 'TS TSRA GR RA BR', 'RA FG BR',
#        'HZ FU', 'RA BR HZ FU', 'MIFG BCFG BR', 'FG+ BCFG BR',
#        'TSRA RA FG+ FG BR HZ', 'FG+', 'TSRA BR SQ', 'TSRA DZ BR HZ',
#        'RA BR HZ VCFG', 'RA FG+ BR', 'FG BR HZ', 'TS HZ',
#        'TS TSRA RA FG BR HZ', 'RA DZ FG+ BR', 'RA DZ FG+ BR HZ',
#        'TSRA FG+ BR HZ', 'RA BR VCFG', 'TS RA BR HZ', 'BCFG BR',
#        'RA SN BR'], dtype=object)

# %%
# Ensuring that each code has proper spacing
codes = ['+FC','FC', 'TS', 'GR', 'RA', 'DZ', 'SN', 'SG', 'GS', 'PL',
         'IC', 'FG+', 'FG', 'BR', 'UP', 'HZ', 'FU', 'VA', 'DU', 'DS',
         'PO', 'SA', 'SS', 'PY', 'SQ', 'DR', 'SH', 'FZ', 'MI', 'PR',
         'BC', 'BL', 'VC']
weather['CodeSum'] = weather['CodeSum'].apply(lambda x: ' '.join([t for t in x.split(' ') if t in codes]))

# %%
# create dummy variables indicate rainy, snowy, windy and misty conditions 
weather["Rain"] = np.where(weather['CodeSum'].str.contains("|".join(['TS', 'RA', 'DZ', 'SH'])), 1, 0)
weather["Snow"] = np.where(weather['CodeSum'].str.contains("|".join(['SN', 'SG', 'GS', 'PL', 'IC', 'DR', 'BC', 'GR'])), 1, 0)
weather["Wind"] = np.where(weather['CodeSum'].str.contains("|".join(['SQ', 'DS', 'SS', 'PO', 'BL'])), 1, 0)
weather["Mist"] = np.where(weather['CodeSum'].str.contains("|".join(['BR', 'HZ', 'FG', 'FU'])), 1, 0)

# %%
weather.tail()
# Out:
#       Station       Date  Tmax  Tmin  Tavg  Depart  DewPoint  WetBulb  Heat  \
# 2939        2 2014-10-29    49    40    45      -2        34       42    20
# 2940        1 2014-10-30    51    32    42      -4        34       40    23
# 2941        2 2014-10-30    53    37    45      -1        35       42    20
# 2942        1 2014-10-31    47    33    40      -6        25       33    25
# 2943        2 2014-10-31    49    34    42      -4        29       36    23
#
#       Cool   CodeSum  PrecipBool  PrecipTotal  StnPressure  SeaLevel  \
# 2939     0                     0         0.00        29.42     30.07
# 2940     0                     0         0.00        29.34     30.09
# 2941     0        RA           1         0.00        29.41     30.10
# 2942     0     RA SN           1         0.03        29.49     30.20
# 2943     0  RA SN BR           1         0.04        29.54     30.20
#
#       ResultSpeed  ResultDir  AvgSpeed  SunHours  Rain  Snow  Wind  Mist
# 2939          8.5         29       9.0     10.50     0     0     0     0
# 2940          5.1         24       5.5     10.45     0     0     0     0
# 2941          5.9         23       6.5     10.45     1     0     0     0
# 2942         22.6         34      22.9     10.40     1     1     0     0
# 2943         21.7         34      22.6     10.40     1     1     0     1

# %%
# now that we have the dummy variables for the key weather conditions, we can drop CodeSum
weather.drop(["CodeSum"], axis=1, inplace=True)

# %% [markdown]
# ### Weather -- Humidity Feature

# %%
weather['Humidity'] = np.round(100-25/9*(weather['Tavg']-weather['DewPoint']),1)

# %%
weather['Humidity'].describe()
# Out:
# count    2944.000000
# mean       61.721603
# std        14.349888
# min         8.300000
# 25%        52.800000
# 50%        61.100000
# 75%        72.200000
# max       105.600000
# Name: Humidity, dtype: float64

# %%
weather.loc[weather['Humidity']>100,'Humidity'] = 100

# %% [markdown]
# ### Weather -- Time Lag Feature

# %% [markdown]
# From research, we know that the following conditions will affect the mosquitos' ability to survive and breed ([Source: Orkin, 2021](https://www.orkin.com/pests/mosquitoes/when-are-mosquitoes-most-active))
#
# Wind, Temperature, Humidity, Precipitation, Drought & Rainfall
#
# Additionally, the entire life cycle of a mosquito, from an egg to an adult, takes approximately 8-10 days ([Source: CDC, 2021](https://www.cdc.gov/dengue/resources/factsheets/mosquitolifecyclefinal.pdf)). Therefore, we will want to monitor the weather conditions after the past 1, 3, 7 and 14 days.

# %%
# split the weather features by stations
weather_df_group1 = weather.loc[weather['Station']==1]
weather_df_group2 = weather.loc[weather['Station']==2]

# %%
# create a variable to store the weather features to do a time lag on
weat_features = ['AvgSpeed', 'DewPoint', 'PrecipTotal', 'ResultDir', 'ResultSpeed', 'SeaLevel', 'StnPressure',
                'Tavg', 'WetBulb', 'SunHours', 'Humidity']

group1_lag_features = weather_df_group1[weat_features]
group2_lag_features = weather_df_group2[weat_features]

# set the number of lags in days
lags = (1, 3, 7, 14)

# assign new columns to the respective dataframes
group1_weather_lag_features = weather_df_group1.assign(**{f'{col}_lag_{n}': 
                                                          group1_lag_features[col].shift(n) for n in lags 
                                                          for col in group1_lag_features})

group2_weather_lag_features = weather_df_group2.assign(**{f'{col}_lag_{n}': 
                                                          group2_lag_features[col].shift(n) for n in lags 
                                                          for col in group2_lag_features})

# %%
# merge both group1_weather_lag_features and group2_weather_lag_features into one dataframe
weather_new_df = pd.concat([group1_weather_lag_features, group2_weather_lag_features])

# %% [markdown]
# ### Train --  Mosquito Species
#
# Of all the mosquitoes collected, only those belonging to species groups - Restuans or Pipiens - had tested positive for the virus in the train dataset. Mosquito Species will likely be a useful predictor. We create weightage of 1 by dummifying it.

# %%
species = ["PIPIENS", "RESTUANS"]

# create loop to create dummified variables to indicate presence of Pipiens & Restuans species
for i in species:
    train[i] = 0
    for index, row in train.iterrows():
        if i in row["Species"]:
            train[i][index] = 1

# %%
train.head()
# Out:
#         Date                                            Address  \
# 0 2007-05-29  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 1 2007-05-29  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 2 2007-05-29  6200 North Mandell Avenue, Chicago, IL 60646, USA
# 3 2007-05-29    7900 West Foster Avenue, Chicago, IL 60656, USA
# 4 2007-05-29    7900 West Foster Avenue, Chicago, IL 60656, USA
#
#                   Species  Block           Street  Trap  \
# 0  CULEX PIPIENS/RESTUANS     41   N OAK PARK AVE  T002
# 1          CULEX RESTUANS     41   N OAK PARK AVE  T002
# 2          CULEX RESTUANS     62    N MANDELL AVE  T007
# 3  CULEX PIPIENS/RESTUANS     79     W FOSTER AVE  T015
# 4          CULEX RESTUANS     79     W FOSTER AVE  T015
#
#               AddressNumberAndStreet   Latitude  Longitude  AddressAccuracy  \
# 0  4100  N OAK PARK AVE, Chicago, IL  41.954690 -87.800991                9
# 1  4100  N OAK PARK AVE, Chicago, IL  41.954690 -87.800991                9
# 2   6200  N MANDELL AVE, Chicago, IL  41.994991 -87.769279                9
# 3    7900  W FOSTER AVE, Chicago, IL  41.974089 -87.824812                8
# 4    7900  W FOSTER AVE, Chicago, IL  41.974089 -87.824812                8
#
#    NumMosquitos  WnvPresent  Month  Week  Year Year Month  \
# 0             1           0      5    22  2007    2007 05
# 1             1           0      5    22  2007    2007 05
# 2             1           0      5    22  2007    2007 05
# 3             1           0      5    22  2007    2007 05
# 4             4           0      5    22  2007    2007 05
#
#                    LatLong                         Coord  Nearest_Station  \
# 0   (41.95469, -87.800991)   POINT (41.95469 -87.800991)                1
# 1   (41.95469, -87.800991)   POINT (41.95469 -87.800991)                1
# 2  (41.994991, -87.769279)  POINT (41.994991 -87.769279)                1
# 3  (41.974089, -87.824812)  POINT (41.974089 -87.824812)                1
# 4  (41.974089, -87.824812)  POINT (41.974089 -87.824812)                1
#
#    PIPIENS  RESTUANS
# 0        1         1
# 1        0         1
# 2        0         1
# 3        1         1
# 4        0         1

# %% [markdown]
# ## Pre-processing

# %%
# renamed 'Nearest_Station' to 'Station'
train.rename(columns = {'Nearest_Station': 'Station'}, inplace=True)
test.rename(columns = {'Nearest_Station': 'Station'}, inplace=True)

# %%
# merge both train/test and weather datasets
train_weather_df = pd.merge(train, weather_new_df, on=['Date', 'Station'])
test_weather_df = pd.merge(test, weather_new_df, on=['Date', 'Station'])

# %%
train_weather_df.head()
# Out:
#         Date                                            Address  \
# 0 2007-05-29  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 1 2007-05-29  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 2 2007-05-29  6200 North Mandell Avenue, Chicago, IL 60646, USA
# 3 2007-05-29    7900 West Foster Avenue, Chicago, IL 60656, USA
# 4 2007-05-29    7900 West Foster Avenue, Chicago, IL 60656, USA
#
#                   Species  Block           Street  Trap  \
# 0  CULEX PIPIENS/RESTUANS     41   N OAK PARK AVE  T002
# 1          CULEX RESTUANS     41   N OAK PARK AVE  T002
# 2          CULEX RESTUANS     62    N MANDELL AVE  T007
# 3  CULEX PIPIENS/RESTUANS     79     W FOSTER AVE  T015
# 4          CULEX RESTUANS     79     W FOSTER AVE  T015
#
#               AddressNumberAndStreet   Latitude  Longitude  AddressAccuracy  \
# 0  4100  N OAK PARK AVE, Chicago, IL  41.954690 -87.800991                9
# 1  4100  N OAK PARK AVE, Chicago, IL  41.954690 -87.800991                9
# 2   6200  N MANDELL AVE, Chicago, IL  41.994991 -87.769279                9
# 3    7900  W FOSTER AVE, Chicago, IL  41.974089 -87.824812                8
# 4    7900  W FOSTER AVE, Chicago, IL  41.974089 -87.824812                8
#
#    NumMosquitos  WnvPresent  Month  Week  Year Year Month  \
# 0             1           0      5    22  2007    2007 05
# 1             1           0      5    22  2007    2007 05
# 2             1           0      5    22  2007    2007 05
# 3             1           0      5    22  2007    2007 05
# 4             4           0      5    22  2007    2007 05
#
#                    LatLong                         Coord  Station  PIPIENS  \
# 0   (41.95469, -87.800991)   POINT (41.95469 -87.800991)        1        1
# 1   (41.95469, -87.800991)   POINT (41.95469 -87.800991)        1        0
# 2  (41.994991, -87.769279)  POINT (41.994991 -87.769279)        1        0
# 3  (41.974089, -87.824812)  POINT (41.974089 -87.824812)        1        1
# 4  (41.974089, -87.824812)  POINT (41.974089 -87.824812)        1        0
#
#    RESTUANS  Tmax  Tmin  Tavg  Depart  DewPoint  WetBulb  Heat  Cool  \
# 0         1    88    60    74      10        58       65     0     9
# 1         1    88    60    74      10        58       65     0     9
# 2         1    88    60    74      10        58       65     0     9
# 3         1    88    60    74      10        58       65     0     9
# 4         1    88    60    74      10        58       65     0     9
#
#    PrecipBool  PrecipTotal  StnPressure  SeaLevel  ResultSpeed  ResultDir  \
# 0           0          0.0        29.39     30.11          5.8         18
# 1           0          0.0        29.39     30.11          5.8         18
# 2           0          0.0        29.39     30.11          5.8         18
# 3           0          0.0        29.39     30.11          5.8         18
# 4           0          0.0        29.39     30.11          5.8         18
#
#    AvgSpeed   SunHours  Rain  Snow  Wind  Mist  Humidity  AvgSpeed_lag_1  \
# 0       6.5  14.933333     0     0     0     1      55.6             5.3
# 1       6.5  14.933333     0     0     0     1      55.6             5.3
# 2       6.5  14.933333     0     0     0     1      55.6             5.3
# 3       6.5  14.933333     0     0     0     1      55.6             5.3
# 4       6.5  14.933333     0     0     0     1      55.6             5.3
#
#    DewPoint_lag_1  PrecipTotal_lag_1  ResultDir_lag_1  ResultSpeed_lag_1  \
# 0            47.0                0.0             10.0                4.8
# 1            47.0                0.0             10.0                4.8
# 2            47.0                0.0             10.0                4.8
# 3            47.0                0.0             10.0                4.8
# 4            47.0                0.0             10.0                4.8
#
#    SeaLevel_lag_1  StnPressure_lag_1  Tavg_lag_1  WetBulb_lag_1  \
# 0           30.15              29.43        65.0           56.0
# 1           30.15              29.43        65.0           56.0
# 2           30.15              29.43        65.0           56.0
# 3           30.15              29.43        65.0           56.0
# 4           30.15              29.43        65.0           56.0
#
#    SunHours_lag_1  Humidity_lag_1  AvgSpeed_lag_3  DewPoint_lag_3  \
# 0       14.916667            50.0             7.2            55.0
# 1       14.916667            50.0             7.2            55.0
# 2       14.916667            50.0             7.2            55.0
# 3       14.916667            50.0             7.2            55.0
# 4       14.916667            50.0             7.2            55.0
#
#    PrecipTotal_lag_3  ResultDir_lag_3  ResultSpeed_lag_3  SeaLevel_lag_3  \
# 0               1.01             17.0                2.8           30.11
# 1               1.01             17.0                2.8           30.11
# 2               1.01             17.0                2.8           30.11
# 3               1.01             17.0                2.8           30.11
# 4               1.01             17.0                2.8           30.11
#
#    StnPressure_lag_3  Tavg_lag_3  WetBulb_lag_3  SunHours_lag_3  \
# 0              29.36        57.0           56.0       14.883333
# 1              29.36        57.0           56.0       14.883333
# 2              29.36        57.0           56.0       14.883333
# 3              29.36        57.0           56.0       14.883333
# 4              29.36        57.0           56.0       14.883333
#
#    Humidity_lag_3  AvgSpeed_lag_7  DewPoint_lag_7  PrecipTotal_lag_7  \
# 0            94.4            10.2            46.0                0.0
# 1            94.4            10.2            46.0                0.0
# 2            94.4            10.2            46.0                0.0
# 3            94.4            10.2            46.0                0.0
# 4            94.4            10.2            46.0                0.0
#
#    ResultDir_lag_7  ResultSpeed_lag_7  SeaLevel_lag_7  StnPressure_lag_7  \
# 0             18.0               10.0           30.06              29.34
# 1             18.0               10.0           30.06              29.34
# 2             18.0               10.0           30.06              29.34
# 3             18.0               10.0           30.06              29.34
# 4             18.0               10.0           30.06              29.34
#
#    Tavg_lag_7  WetBulb_lag_7  SunHours_lag_7  Humidity_lag_7  AvgSpeed_lag_14  \
# 0        71.0           58.0       14.766667            30.6             12.3
# 1        71.0           58.0       14.766667            30.6             12.3
# 2        71.0           58.0       14.766667            30.6             12.3
# 3        71.0           58.0       14.766667            30.6             12.3
# 4        71.0           58.0       14.766667            30.6             12.3
#
#    DewPoint_lag_14  PrecipTotal_lag_14  ResultDir_lag_14  ResultSpeed_lag_14  \
# 0             56.0                0.38              27.0                 8.1
# 1             56.0                0.38              27.0                 8.1
# 2             56.0                0.38              27.0                 8.1
# 3             56.0                0.38              27.0                 8.1
# 4             56.0                0.38              27.0                 8.1
#
#    SeaLevel_lag_14  StnPressure_lag_14  Tavg_lag_14  WetBulb_lag_14  \
# 0            29.84               29.13         69.0            61.0
# 1            29.84               29.13         69.0            61.0
# 2            29.84               29.13         69.0            61.0
# 3            29.84               29.13         69.0            61.0
# 4            29.84               29.13         69.0            61.0
#
#    SunHours_lag_14  Humidity_lag_14
# 0        14.533333             63.9
# 1        14.533333             63.9
# 2        14.533333             63.9
# 3        14.533333             63.9
# 4        14.533333             63.9

# %%
train_weather_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9693 entries, 0 to 9692
# Data columns (total 86 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Date                    9693 non-null   datetime64[ns]
#  1   Address                 9693 non-null   object
#  2   Species                 9693 non-null   object
#  3   Block                   9693 non-null   int64
#  4   Street                  9693 non-null   object
#  5   Trap                    9693 non-null   object
#  6   AddressNumberAndStreet  9693 non-null   object
#  7   Latitude                9693 non-null   float64
#  8   Longitude               9693 non-null   float64
#  9   AddressAccuracy         9693 non-null   int64
#  10  NumMosquitos            9693 non-null   int64
#  11  WnvPresent              9693 non-null   int64
#  12  Month                   9693 non-null   int64
#  13  Week                    9693 non-null   int64
#  14  Year                    9693 non-null   int64
#  15  Year Month              9693 non-null   object
#  16  LatLong                 9693 non-null   object
#  17  Coord                   9693 non-null   object
#  18  Station                 9693 non-null   int64
#  19  PIPIENS                 9693 non-null   int64
#  20  RESTUANS                9693 non-null   int64
#  21  Tmax                    9693 non-null   int64
#  22  Tmin                    9693 non-null   int64
#  23  Tavg                    9693 non-null   int64
#  24  Depart                  9693 non-null   int64
#  25  DewPoint                9693 non-null   int64
#  26  WetBulb                 9693 non-null   int64
#  27  Heat                    9693 non-null   int64
#  28  Cool                    9693 non-null   int64
#  29  PrecipBool              9693 non-null   int64
#  30  PrecipTotal             9693 non-null   float64
#  31  StnPressure             9693 non-null   float64
#  32  SeaLevel                9693 non-null   float64
#  33  ResultSpeed             9693 non-null   float64
#  34  ResultDir               9693 non-null   int64
#  35  AvgSpeed                9693 non-null   float64
#  36  SunHours                9693 non-null   float64
#  37  Rain                    9693 non-null   int32
#  38  Snow                    9693 non-null   int32
#  39  Wind                    9693 non-null   int32
#  40  Mist                    9693 non-null   int32
#  41  Humidity                9693 non-null   float64
#  42  AvgSpeed_lag_1          9693 non-null   float64
#  43  DewPoint_lag_1          9693 non-null   float64
#  44  PrecipTotal_lag_1       9693 non-null   float64
#  45  ResultDir_lag_1         9693 non-null   float64
#  46  ResultSpeed_lag_1       9693 non-null   float64
#  47  SeaLevel_lag_1          9693 non-null   float64
#  48  StnPressure_lag_1       9693 non-null   float64
#  49  Tavg_lag_1              9693 non-null   float64
#  50  WetBulb_lag_1           9693 non-null   float64
#  51  SunHours_lag_1          9693 non-null   float64
#  52  Humidity_lag_1          9693 non-null   float64
#  53  AvgSpeed_lag_3          9693 non-null   float64
#  54  DewPoint_lag_3          9693 non-null   float64
#  55  PrecipTotal_lag_3       9693 non-null   float64
#  56  ResultDir_lag_3         9693 non-null   float64
#  57  ResultSpeed_lag_3       9693 non-null   float64
#  58  SeaLevel_lag_3          9693 non-null   float64
#  59  StnPressure_lag_3       9693 non-null   float64
#  60  Tavg_lag_3              9693 non-null   float64
#  61  WetBulb_lag_3           9693 non-null   float64
#  62  SunHours_lag_3          9693 non-null   float64
#  63  Humidity_lag_3          9693 non-null   float64
#  64  AvgSpeed_lag_7          9693 non-null   float64
#  65  DewPoint_lag_7          9693 non-null   float64
#  66  PrecipTotal_lag_7       9693 non-null   float64
#  67  ResultDir_lag_7         9693 non-null   float64
#  68  ResultSpeed_lag_7       9693 non-null   float64
#  69  SeaLevel_lag_7          9693 non-null   float64
#  70  StnPressure_lag_7       9693 non-null   float64
#  71  Tavg_lag_7              9693 non-null   float64
#  72  WetBulb_lag_7           9693 non-null   float64
#  73  SunHours_lag_7          9693 non-null   float64
#  74  Humidity_lag_7          9693 non-null   float64
#  75  AvgSpeed_lag_14         9693 non-null   float64
#  76  DewPoint_lag_14         9693 non-null   float64
#  77  PrecipTotal_lag_14      9693 non-null   float64
#  78  ResultDir_lag_14        9693 non-null   float64
#  79  ResultSpeed_lag_14      9693 non-null   float64
#  80  SeaLevel_lag_14         9693 non-null   float64
#  81  StnPressure_lag_14      9693 non-null   float64
#  82  Tavg_lag_14             9693 non-null   float64
#  83  WetBulb_lag_14          9693 non-null   float64
#  84  SunHours_lag_14         9693 non-null   float64
#  85  Humidity_lag_14         9693 non-null   float64
# dtypes: datetime64[ns](1), float64(53), int32(4), int64(20), object(8)
# memory usage: 6.3+ MB

# %%
test_weather_df.head()
# Out:
#    Id       Date                                            Address  \
# 0   1 2008-06-11  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 1   2 2008-06-11  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 2   3 2008-06-11  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 3   4 2008-06-11  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 4   5 2008-06-11  4100 North Oak Park Avenue, Chicago, IL 60634,...
#
#                   Species  Block           Street  Trap  \
# 0  CULEX PIPIENS/RESTUANS     41   N OAK PARK AVE  T002
# 1          CULEX RESTUANS     41   N OAK PARK AVE  T002
# 2           CULEX PIPIENS     41   N OAK PARK AVE  T002
# 3        CULEX SALINARIUS     41   N OAK PARK AVE  T002
# 4         CULEX TERRITANS     41   N OAK PARK AVE  T002
#
#               AddressNumberAndStreet  Latitude  Longitude  AddressAccuracy  \
# 0  4100  N OAK PARK AVE, Chicago, IL  41.95469 -87.800991                9
# 1  4100  N OAK PARK AVE, Chicago, IL  41.95469 -87.800991                9
# 2  4100  N OAK PARK AVE, Chicago, IL  41.95469 -87.800991                9
# 3  4100  N OAK PARK AVE, Chicago, IL  41.95469 -87.800991                9
# 4  4100  N OAK PARK AVE, Chicago, IL  41.95469 -87.800991                9
#
#    Month  Week  Year Year Month                 LatLong  \
# 0      6    24  2008    2008 06  (41.95469, -87.800991)
# 1      6    24  2008    2008 06  (41.95469, -87.800991)
# 2      6    24  2008    2008 06  (41.95469, -87.800991)
# 3      6    24  2008    2008 06  (41.95469, -87.800991)
# 4      6    24  2008    2008 06  (41.95469, -87.800991)
#
#                          Coord  Station  Tmax  Tmin  Tavg  Depart  DewPoint  \
# 0  POINT (41.95469 -87.800991)        1    86    61    74       7        56
# 1  POINT (41.95469 -87.800991)        1    86    61    74       7        56
# 2  POINT (41.95469 -87.800991)        1    86    61    74       7        56
# 3  POINT (41.95469 -87.800991)        1    86    61    74       7        56
# 4  POINT (41.95469 -87.800991)        1    86    61    74       7        56
#
#    WetBulb  Heat  Cool  PrecipBool  PrecipTotal  StnPressure  SeaLevel  \
# 0       64     0     9           0          0.0        29.28     29.99
# 1       64     0     9           0          0.0        29.28     29.99
# 2       64     0     9           0          0.0        29.28     29.99
# 3       64     0     9           0          0.0        29.28     29.99
# 4       64     0     9           0          0.0        29.28     29.99
#
#    ResultSpeed  ResultDir  AvgSpeed   SunHours  Rain  Snow  Wind  Mist  \
# 0          8.9         18      10.0  15.166667     0     0     0     0
# 1          8.9         18      10.0  15.166667     0     0     0     0
# 2          8.9         18      10.0  15.166667     0     0     0     0
# 3          8.9         18      10.0  15.166667     0     0     0     0
# 4          8.9         18      10.0  15.166667     0     0     0     0
#
#    Humidity  AvgSpeed_lag_1  DewPoint_lag_1  PrecipTotal_lag_1  \
# 0      50.0             9.6            56.0                0.0
# 1      50.0             9.6            56.0                0.0
# 2      50.0             9.6            56.0                0.0
# 3      50.0             9.6            56.0                0.0
# 4      50.0             9.6            56.0                0.0
#
#    ResultDir_lag_1  ResultSpeed_lag_1  SeaLevel_lag_1  StnPressure_lag_1  \
# 0             25.0                8.8           29.89              29.18
# 1             25.0                8.8           29.89              29.18
# 2             25.0                8.8           29.89              29.18
# 3             25.0                8.8           29.89              29.18
# 4             25.0                8.8           29.89              29.18
#
#    Tavg_lag_1  WetBulb_lag_1  SunHours_lag_1  Humidity_lag_1  AvgSpeed_lag_3  \
# 0        69.0           61.0       15.166667            63.9            12.2
# 1        69.0           61.0       15.166667            63.9            12.2
# 2        69.0           61.0       15.166667            63.9            12.2
# 3        69.0           61.0       15.166667            63.9            12.2
# 4        69.0           61.0       15.166667            63.9            12.2
#
#    DewPoint_lag_3  PrecipTotal_lag_3  ResultDir_lag_3  ResultSpeed_lag_3  \
# 0            68.0               1.24             18.0                6.5
# 1            68.0               1.24             18.0                6.5
# 2            68.0               1.24             18.0                6.5
# 3            68.0               1.24             18.0                6.5
# 4            68.0               1.24             18.0                6.5
#
#    SeaLevel_lag_3  StnPressure_lag_3  Tavg_lag_3  WetBulb_lag_3  \
# 0           29.81              29.11        75.0           70.0
# 1           29.81              29.11        75.0           70.0
# 2           29.81              29.11        75.0           70.0
# 3           29.81              29.11        75.0           70.0
# 4           29.81              29.11        75.0           70.0
#
#    SunHours_lag_3  Humidity_lag_3  AvgSpeed_lag_7  DewPoint_lag_7  \
# 0       15.133333            80.6             5.2            59.0
# 1       15.133333            80.6             5.2            59.0
# 2       15.133333            80.6             5.2            59.0
# 3       15.133333            80.6             5.2            59.0
# 4       15.133333            80.6             5.2            59.0
#
#    PrecipTotal_lag_7  ResultDir_lag_7  ResultSpeed_lag_7  SeaLevel_lag_7  \
# 0                0.0              4.0                4.5           29.62
# 1                0.0              4.0                4.5           29.62
# 2                0.0              4.0                4.5           29.62
# 3                0.0              4.0                4.5           29.62
# 4                0.0              4.0                4.5           29.62
#
#    StnPressure_lag_7  Tavg_lag_7  WetBulb_lag_7  SunHours_lag_7  \
# 0               28.9        66.0           61.0       15.066667
# 1               28.9        66.0           61.0       15.066667
# 2               28.9        66.0           61.0       15.066667
# 3               28.9        66.0           61.0       15.066667
# 4               28.9        66.0           61.0       15.066667
#
#    Humidity_lag_7  AvgSpeed_lag_14  DewPoint_lag_14  PrecipTotal_lag_14  \
# 0            80.6              8.7             32.0                 0.0
# 1            80.6              8.7             32.0                 0.0
# 2            80.6              8.7             32.0                 0.0
# 3            80.6              8.7             32.0                 0.0
# 4            80.6              8.7             32.0                 0.0
#
#    ResultDir_lag_14  ResultSpeed_lag_14  SeaLevel_lag_14  StnPressure_lag_14  \
# 0               6.0                 8.2            30.34                29.6
# 1               6.0                 8.2            30.34                29.6
# 2               6.0                 8.2            30.34                29.6
# 3               6.0                 8.2            30.34                29.6
# 4               6.0                 8.2            30.34                29.6
#
#    Tavg_lag_14  WetBulb_lag_14  SunHours_lag_14  Humidity_lag_14
# 0         53.0            43.0        14.916667             41.7
# 1         53.0            43.0        14.916667             41.7
# 2         53.0            43.0        14.916667             41.7
# 3         53.0            43.0        14.916667             41.7
# 4         53.0            43.0        14.916667             41.7

# %%
test_weather_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 116293 entries, 0 to 116292
# Data columns (total 83 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Id                      116293 non-null  int64
#  1   Date                    116293 non-null  datetime64[ns]
#  2   Address                 116293 non-null  object
#  3   Species                 116293 non-null  object
#  4   Block                   116293 non-null  int64
#  5   Street                  116293 non-null  object
#  6   Trap                    116293 non-null  object
#  7   AddressNumberAndStreet  116293 non-null  object
#  8   Latitude                116293 non-null  float64
#  9   Longitude               116293 non-null  float64
#  10  AddressAccuracy         116293 non-null  int64
#  11  Month                   116293 non-null  int64
#  12  Week                    116293 non-null  int64
#  13  Year                    116293 non-null  int64
#  14  Year Month              116293 non-null  object
#  15  LatLong                 116293 non-null  object
#  16  Coord                   116293 non-null  object
#  17  Station                 116293 non-null  int64
#  18  Tmax                    116293 non-null  int64
#  19  Tmin                    116293 non-null  int64
#  20  Tavg                    116293 non-null  int64
#  21  Depart                  116293 non-null  int64
#  22  DewPoint                116293 non-null  int64
#  23  WetBulb                 116293 non-null  int64
#  24  Heat                    116293 non-null  int64
#  25  Cool                    116293 non-null  int64
#  26  PrecipBool              116293 non-null  int64
#  27  PrecipTotal             116293 non-null  float64
#  28  StnPressure             116293 non-null  float64
#  29  SeaLevel                116293 non-null  float64
#  30  ResultSpeed             116293 non-null  float64
#  31  ResultDir               116293 non-null  int64
#  32  AvgSpeed                116293 non-null  float64
#  33  SunHours                116293 non-null  float64
#  34  Rain                    116293 non-null  int32
#  35  Snow                    116293 non-null  int32
#  36  Wind                    116293 non-null  int32
#  37  Mist                    116293 non-null  int32
#  38  Humidity                116293 non-null  float64
#  39  AvgSpeed_lag_1          116293 non-null  float64
#  40  DewPoint_lag_1          116293 non-null  float64
#  41  PrecipTotal_lag_1       116293 non-null  float64
#  42  ResultDir_lag_1         116293 non-null  float64
#  43  ResultSpeed_lag_1       116293 non-null  float64
#  44  SeaLevel_lag_1          116293 non-null  float64
#  45  StnPressure_lag_1       116293 non-null  float64
#  46  Tavg_lag_1              116293 non-null  float64
#  47  WetBulb_lag_1           116293 non-null  float64
#  48  SunHours_lag_1          116293 non-null  float64
#  49  Humidity_lag_1          116293 non-null  float64
#  50  AvgSpeed_lag_3          116293 non-null  float64
#  51  DewPoint_lag_3          116293 non-null  float64
#  52  PrecipTotal_lag_3       116293 non-null  float64
#  53  ResultDir_lag_3         116293 non-null  float64
#  54  ResultSpeed_lag_3       116293 non-null  float64
#  55  SeaLevel_lag_3          116293 non-null  float64
#  56  StnPressure_lag_3       116293 non-null  float64
#  57  Tavg_lag_3              116293 non-null  float64
#  58  WetBulb_lag_3           116293 non-null  float64
#  59  SunHours_lag_3          116293 non-null  float64
#  60  Humidity_lag_3          116293 non-null  float64
#  61  AvgSpeed_lag_7          116293 non-null  float64
#  62  DewPoint_lag_7          116293 non-null  float64
#  63  PrecipTotal_lag_7       116293 non-null  float64
#  64  ResultDir_lag_7         116293 non-null  float64
#  65  ResultSpeed_lag_7       116293 non-null  float64
#  66  SeaLevel_lag_7          116293 non-null  float64
#  67  StnPressure_lag_7       116293 non-null  float64
#  68  Tavg_lag_7              116293 non-null  float64
#  69  WetBulb_lag_7           116293 non-null  float64
#  70  SunHours_lag_7          116293 non-null  float64
#  71  Humidity_lag_7          116293 non-null  float64
#  72  AvgSpeed_lag_14         116293 non-null  float64
#  73  DewPoint_lag_14         116293 non-null  float64
#  74  PrecipTotal_lag_14      116293 non-null  float64
#  75  ResultDir_lag_14        116293 non-null  float64
#  76  ResultSpeed_lag_14      116293 non-null  float64
#  77  SeaLevel_lag_14         116293 non-null  float64
#  78  StnPressure_lag_14      116293 non-null  float64
#  79  Tavg_lag_14             116293 non-null  float64
#  80  WetBulb_lag_14          116293 non-null  float64
#  81  SunHours_lag_14         116293 non-null  float64
#  82  Humidity_lag_14         116293 non-null  float64
# dtypes: datetime64[ns](1), float64(53), int32(4), int64(17), object(8)
# memory usage: 72.8+ MB

# %%
# apply one-hot encoding in train_weather_df
train_weather_encoded_df = pd.get_dummies(train_weather_df, columns=['Trap', 'Species'])

# %%
# drop additional columns not required for modelling
train_weather_encoded_df = train_weather_encoded_df.drop(columns=['Date', 'Address', 'Street', 'AddressNumberAndStreet', 
                                                                  'Year Month', 'LatLong', 'Coord'])

# %%
# apply one-hot encoding in test_weather_df
test_weather_encoded_df = pd.get_dummies(train_weather_df, columns=['Trap', 'Species'])

# %%
# drop additional columns not required for modelling
test_weather_encoded_df = test_weather_encoded_df.drop(columns=['Date', 'Address', 'Street', 'AddressNumberAndStreet', 
                                                                  'Year Month', 'LatLong', 'Coord'])

# %%
# obtain X and y variables
X = train_weather_encoded_df[[col for col in train_weather_encoded_df.columns if 'WnvPresent' not in col]]._get_numeric_data()
y = train_weather_encoded_df['WnvPresent']

# %%
# define constants for modelling
RS = 42 # random state
CV = 5 # cross val
SCORE = 'roc_auc' # scoring

# %%
kf = KFold(n_splits=CV, random_state=RS, shuffle=True)

# %%
# train test split
# shuffle=False to account for timelag
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=RS, stratify=y)

# %%
print('X_train shape: {}'.format(X_train.shape))
print('y_train shape: {}'.format(y_test.shape))
print('X_test shape: {}'.format(X_test.shape))
print('y_test shape: {}'.format(y_test.shape))
# Out:
# X_train shape: (8723, 219)
# y_train shape: (970,)
# X_test shape: (970, 219)
# y_test shape: (970,)

# %% [markdown]
# ## Baseline Prediction

# %%
# Look at the proportions of each outcome
y_train.value_counts(normalize=True)
# Out:
# 0    0.948068
# 1    0.051932
# Name: WnvPresent, dtype: float64

# %% [markdown]
# We observe that the data is heavily imbalanced. We will be 95% accurate if we were to predict all to be the negative class (WNV not present). As such, we will be optimizing our models using AUC score instead of accuracy. We will also deploy SMOTE (Synthetic Minority Over-sampling Technique) to help us with over-sampling.

# %% [markdown]
# ## Modelling

# %%
# dictionary to hold the metrics for each runs
metrics = {}
# dictionary to hold the models for each runs
models = {}
# Dataframe to hold the predictions for validataion set
val_preds_df = X_test.copy()

# %%
sm = SMOTE(random_state=RS)
X_train, y_train = sm.fit_sample(X_train, y_train)

# %%
# after SMOTE()
y_train.value_counts(normalize=True)
# Out:
# 0    0.5
# 1    0.5
# Name: WnvPresent, dtype: float64

# %%
# Function to fit and collect model metrics
def model_metrics(tag, pipe, param, X_tr, X_ts, y_tr, y_ts, models, preds_df):
    """ 
    Function to fit and collect model metrics
  
    Parameters: 
        tag (str): name for this pipeline
        pipe (pipeline): pipeline to be executed
		param (dict): dictionary of parameters to be used
        X_tr (Series): Series holding the train feature
        X_ts (Series): Series holding the test feature
        y_tr (Series): Series holding the train target
        y_ts (Series): Series holding the test target
  
    Returns: 
		None:
  
    """
    gs = GridSearchCV(pipe, param_grid=param, cv=kf, scoring=SCORE)
    gs.fit(X_tr, y_tr)
    bm = gs.best_estimator_
    models[tag] = gs
    y_pred = bm.predict(X_ts)
    preds_df[tag]=y_pred
    print(f'{tag}->Best params: {gs.best_params_}')
    
    metric = {}
    metric['01 Train score'] = f'{bm.score(X_tr, y_tr):,.4f}'
    metric['02 Test score'] = f'{bm.score(X_ts, y_ts):,.4f}'
    metric['03 Score diff'] = float(metric['01 Train score'])-float(metric['02 Test score'])
    metric['04 Train recall'] = f'{recall_score(y_tr, bm.predict(X_tr)):,.4f}'
    metric['05 Test recall'] = f'{recall_score(y_ts, y_pred):,.4f}'

    # calculate Specificity and Sensitivity
    tn, fp, fn, tp = confusion_matrix(y_ts, y_pred).ravel()
    metric['06 Precision'] = f'{(tp /(tp + fp)):.4f}'
    metric['07 Specificity'] = f'{(tn / (tn + fp)):.4f}'
    metric['08 Sensitivity'] = f'{(tp / (tp + fn)):.4f}'
    metric['09 True Negatives'] = tn
    metric['10 False Positives'] = fp
    metric['11 False Negatives'] = fn
    metric['12 True Positives'] = tp
    metric['13 Train ROC Score'] = f'{roc_auc_score(y_tr, bm.predict_proba(X_tr)[:,1]):,.4f}'
    metric['14 Test ROC Score'] = f'{roc_auc_score(y_ts, bm.predict_proba(X_ts)[:,1]):,.4f}'
    metric['15 Train CV Score'] = f'{cross_val_score(bm, X_tr, y_tr, cv=CV).mean():,.4f}'
    metric['16 Test CV Score'] = f'{cross_val_score(bm, X_ts, y_ts, cv=CV).mean():,.4f}'

    # plot roc and confusion matrix
    fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(12,5))
    plot_roc_curve(gs, X_ts, y_ts, name=tag, ax=ax[0]);
    # Plot baseline. (Perfect overlap between the two populations.)
    ax[0].plot(np.linspace(0, 1, 200), np.linspace(0, 1, 200),
             label='baseline', linestyle='--')
    plot_confusion_matrix(gs, X_ts, y_ts, ax=ax[1], cmap='RdPu');
    ax[0].set_title(f'ROC for {tag}');
    ax[1].set_title(f'Confusion Matrix for {tag}');
    
    return metric

# %% [markdown]
# ### Logistic Regression

# %%
# Creating a pipeline model for StandardScaler, SMOTE and Logistic Regression
lr_pipe = Pipeline([
        ('ss', StandardScaler()),
        ('lr', LogisticRegression(random_state=RS, max_iter=5000))
    ])
# Paramters
lr_params = {'lr__C': np.linspace(0.1, 1, 20)}

# %%
metrics['log_reg'] = model_metrics('log_reg', lr_pipe, lr_params, X_train, X_test, 
                                   y_train, y_test, models, val_preds_df)
pd.DataFrame(metrics)
# Out:
# log_reg->Best params: {'lr__C': 0.1}
#                    log_reg
# 01 Train score      0.9658
# 02 Test score       0.9495
# 03 Score diff       0.0163
# 04 Train recall     0.9472
# 05 Test recall      0.2200
# 06 Precision        0.5238
# 07 Specificity      0.9891
# 08 Sensitivity      0.2200
# 09 True Negatives      910
# 10 False Positives      10
# 11 False Negatives      39
# 12 True Positives       11
# 13 Train ROC Score  0.9938
# 14 Test ROC Score   0.8901
# 15 Train CV Score   0.9598
# 16 Test CV Score    0.9485

# %% [markdown]
# ### KNeighborsClassifier

# %%
# Creating a pipeline model for StandardScaler, SMOTE and Random Forest
knn_pipe = Pipeline([
        ('ss', StandardScaler()),
        ('knn', KNeighborsClassifier())
    ])
# Paratmeters
knn_params = {
    'memory': [None, 1],
    'verbose': [True, False]
}

# %%
metrics['k_neighbor'] = model_metrics('k_neighbor', knn_pipe, knn_params, X_train, X_test, 
                                         y_train, y_test, models, val_preds_df)
pd.DataFrame(metrics)
# Out:
# [Pipeline] ................ (step 1 of 2) Processing ss, total=   0.1s
# [Pipeline] ............... (step 2 of 2) Processing knn, total=   0.0s
# [Pipeline] ................ (step 1 of 2) Processing ss, total=   0.1s
# [Pipeline] ............... (step 2 of 2) Processing knn, total=   0.0s
# [Pipeline] ................ (step 1 of 2) Processing ss, total=   0.1s
# [Pipeline] ............... (step 2 of 2) Processing knn, total=   0.0s
# [Pipeline] ................ (step 1 of 2) Processing ss, total=   0.1s
# [Pipeline] ............... (step 2 of 2) Processing knn, total=   0.0s
# [Pipeline] ................ (step 1 of 2) Processing ss, total=   0.1s
# [Pipeline] ............... (step 2 of 2) Processing knn, total=   0.0s
# [Pipeline] ................ (step 1 of 2) Processing ss, total=   0.1s
# [Pipeline] ............... (step 2 of 2) Processing knn, total=   0.0s
# k_neighbor->Best params: {'memory': None, 'verbose': True}
# [Pipeline] ................ (step 1 of 2) Processing ss, total=   0.1s
# [Pipeline] ............... (step 2 of 2) Processing knn, total=   0.0s
# [Pipeline] ................ (step 1 of 2) Processing ss, total=   0.1s
# [Pipeline] ............... (step 2 of 2) Processing knn, total=   0.0s
# [Pipeline] ................ (step 1 of 2) Processing ss, total=   0.1s
# [Pipeline] ............... (step 2 of 2) Processing knn, total=   0.0s
# [Pipeline] ................ (step 1 of 2) Processing ss, total=   0.1s
# [Pipeline] ............... (step 2 of 2) Processing knn, total=   0.0s
# [Pipeline] ................ (step 1 of 2) Processing ss, total=   0.1s
# [Pipeline] ............... (step 2 of 2) Processing knn, total=   0.0s
# [Pipeline] ................ (step 1 of 2) Processing ss, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing knn, total=   0.0s
# [Pipeline] ................ (step 1 of 2) Processing ss, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing knn, total=   0.0s
# [Pipeline] ................ (step 1 of 2) Processing ss, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing knn, total=   0.0s
# [Pipeline] ................ (step 1 of 2) Processing ss, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing knn, total=   0.0s
# [Pipeline] ................ (step 1 of 2) Processing ss, total=   0.0s
# [Pipeline] ............... (step 2 of 2) Processing knn, total=   0.0s
#                    log_reg k_neighbor
# 01 Train score      0.9658     0.9720
# 02 Test score       0.9495     0.9227
# 03 Score diff       0.0163     0.0493
# 04 Train recall     0.9472     0.9676
# 05 Test recall      0.2200     0.1200
# 06 Precision        0.5238     0.1622
# 07 Specificity      0.9891     0.9663
# 08 Sensitivity      0.2200     0.1200
# 09 True Negatives      910        889
# 10 False Positives      10         31
# 11 False Negatives      39         44
# 12 True Positives       11          6
# 13 Train ROC Score  0.9938     0.9968
# 14 Test ROC Score   0.8901     0.6454
# 15 Train CV Score   0.9598     0.9591
# 16 Test CV Score    0.9485     0.9485

# %% [markdown]
# ### Random Forest

# %%
# Creating a pipeline model for StandardScaler, SMOTE and Random Forest
rf_pipe = Pipeline([
        ('ss', StandardScaler()),
        ('rf', RandomForestClassifier(random_state=RS))
    ])
# Paratmeters
rf_params = {
    'rf__max_depth': [None, 3],
    'rf__n_estimators': [150, 200]
}

# %%
metrics['random_forest'] = model_metrics('random_forest', rf_pipe, rf_params, X_train, X_test, 
                                         y_train, y_test, models, val_preds_df)
pd.DataFrame(metrics)
# Out:
# random_forest->Best params: {'rf__max_depth': None, 'rf__n_estimators': 200}
#                    log_reg k_neighbor random_forest
# 01 Train score      0.9658     0.9720        0.9976
# 02 Test score       0.9495     0.9227        0.9216
# 03 Score diff       0.0163     0.0493         0.076
# 04 Train recall     0.9472     0.9676        0.9977
# 05 Test recall      0.2200     0.1200        0.2800
# 06 Precision        0.5238     0.1622        0.2593
# 07 Specificity      0.9891     0.9663        0.9565
# 08 Sensitivity      0.2200     0.1200        0.2800
# 09 True Negatives      910        889           880
# 10 False Positives      10         31            40
# 11 False Negatives      39         44            36
# 12 True Positives       11          6            14
# 13 Train ROC Score  0.9938     0.9968        1.0000
# 14 Test ROC Score   0.8901     0.6454        0.8207
# 15 Train CV Score   0.9598     0.9591        0.9588
# 16 Test CV Score    0.9485     0.9485        0.9454

# %% [markdown]
# ### Extra Tree

# %%
# Creating a pipeline model for StandardScaler, SMOTE and Extra Trees
et_pipe = Pipeline([
        ('ss', StandardScaler()),
        ('et', ExtraTreesClassifier(random_state=RS, n_jobs=-1))
    ])
# Parameters
et_params = {'et__n_estimators': [500],
             'et__min_samples_split': [2],
             'et__min_samples_leaf': [5],
             'et__ccp_alpha': [0]}

# %%
metrics['extra_trees'] = model_metrics('extra_trees', et_pipe, et_params, X_train, X_test, 
                                       y_train, y_test, models, val_preds_df)
pd.DataFrame(metrics)
# Out:
# extra_trees->Best params: {'et__ccp_alpha': 0, 'et__min_samples_leaf': 5, 'et__min_samples_split': 2, 'et__n_estimators': 500}
#                    log_reg k_neighbor random_forest extra_trees
# 01 Train score      0.9658     0.9720        0.9976      0.9229
# 02 Test score       0.9495     0.9227        0.9216      0.8722
# 03 Score diff       0.0163     0.0493         0.076      0.0507
# 04 Train recall     0.9472     0.9676        0.9977      0.9539
# 05 Test recall      0.2200     0.1200        0.2800      0.5000
# 06 Precision        0.5238     0.1622        0.2593      0.2016
# 07 Specificity      0.9891     0.9663        0.9565      0.8924
# 08 Sensitivity      0.2200     0.1200        0.2800      0.5000
# 09 True Negatives      910        889           880         821
# 10 False Positives      10         31            40          99
# 11 False Negatives      39         44            36          25
# 12 True Positives       11          6            14          25
# 13 Train ROC Score  0.9938     0.9968        1.0000      0.9853
# 14 Test ROC Score   0.8901     0.6454        0.8207      0.8364
# 15 Train CV Score   0.9598     0.9591        0.9588      0.9126
# 16 Test CV Score    0.9485     0.9485        0.9454      0.9485

# %% [markdown]
# ### GradientBoostingClassifier

# %%
# pipeline
gboost_pipe = Pipeline([
        ('ss', StandardScaler()),
        ('gboost', GradientBoostingClassifier(random_state=RS))
])
# Parameters
gboost_params = {
    'gboost__n_estimators': [80, 100, 120, 150],
    'gboost__max_depth': [1, 2, 3],
    'gboost__min_samples_split': [2, 4],
    'gboost__min_samples_leaf': [1, 2]
}

# %%
metrics['gboost'] = model_metrics('gboost', gboost_pipe, gboost_params, X_train, X_test, 
                                   y_train, y_test, models, val_preds_df)
pd.DataFrame(metrics)
# Out:
# gboost->Best params: {'gboost__max_depth': 3, 'gboost__min_samples_leaf': 2, 'gboost__min_samples_split': 2, 'gboost__n_estimators': 150}
#                    log_reg k_neighbor random_forest extra_trees  gboost
# 01 Train score      0.9658     0.9720        0.9976      0.9229  0.9320
# 02 Test score       0.9495     0.9227        0.9216      0.8722  0.9041
# 03 Score diff       0.0163     0.0493         0.076      0.0507  0.0279
# 04 Train recall     0.9472     0.9676        0.9977      0.9539  0.9445
# 05 Test recall      0.2200     0.1200        0.2800      0.5000  0.6000
# 06 Precision        0.5238     0.1622        0.2593      0.2016  0.2913
# 07 Specificity      0.9891     0.9663        0.9565      0.8924  0.9207
# 08 Sensitivity      0.2200     0.1200        0.2800      0.5000  0.6000
# 09 True Negatives      910        889           880         821     847
# 10 False Positives      10         31            40          99      73
# 11 False Negatives      39         44            36          25      20
# 12 True Positives       11          6            14          25      30
# 13 Train ROC Score  0.9938     0.9968        1.0000      0.9853  0.9855
# 14 Test ROC Score   0.8901     0.6454        0.8207      0.8364  0.8889
# 15 Train CV Score   0.9598     0.9591        0.9588      0.9126  0.9221
# 16 Test CV Score    0.9485     0.9485        0.9454      0.9485  0.9299

# %% [markdown]
# ### AdaBoost

# %%
# Pipeline
ada_pipe = Pipeline([
        ('ss', StandardScaler()),
        ('ada', AdaBoostClassifier(random_state=RS))
    ])

# Hyperparameters
ada_params = {
    'ada__n_estimators': [20, 30, 40, 50],
    'ada__learning_rate': [0.8, 0.9, 1]
}

# %%
metrics['ada'] = model_metrics('ada', ada_pipe, ada_params, X_train, X_test, 
                                   y_train, y_test, models, val_preds_df)
pd.DataFrame(metrics)
# Out:
# ada->Best params: {'ada__learning_rate': 1, 'ada__n_estimators': 50}
#                    log_reg k_neighbor random_forest extra_trees  gboost  \
# 01 Train score      0.9658     0.9720        0.9976      0.9229  0.9320
# 02 Test score       0.9495     0.9227        0.9216      0.8722  0.9041
# 03 Score diff       0.0163     0.0493         0.076      0.0507  0.0279
# 04 Train recall     0.9472     0.9676        0.9977      0.9539  0.9445
# 05 Test recall      0.2200     0.1200        0.2800      0.5000  0.6000
# 06 Precision        0.5238     0.1622        0.2593      0.2016  0.2913
# 07 Specificity      0.9891     0.9663        0.9565      0.8924  0.9207
# 08 Sensitivity      0.2200     0.1200        0.2800      0.5000  0.6000
# 09 True Negatives      910        889           880         821     847
# 10 False Positives      10         31            40          99      73
# 11 False Negatives      39         44            36          25      20
# 12 True Positives       11          6            14          25      30
# 13 Train ROC Score  0.9938     0.9968        1.0000      0.9853  0.9855
# 14 Test ROC Score   0.8901     0.6454        0.8207      0.8364  0.8889
# 15 Train CV Score   0.9598     0.9591        0.9588      0.9126  0.9221
# 16 Test CV Score    0.9485     0.9485        0.9454      0.9485  0.9299
#
#                        ada
# 01 Train score      0.9026
# 02 Test score       0.8794
# 03 Score diff       0.0232
# 04 Train recall     0.9248
# 05 Test recall      0.5800
# 06 Precision        0.2320
# 07 Specificity      0.8957
# 08 Sensitivity      0.5800
# 09 True Negatives      824
# 10 False Positives      96
# 11 False Negatives      21
# 12 True Positives       29
# 13 Train ROC Score  0.9709
# 14 Test ROC Score   0.8571
# 15 Train CV Score   0.8980
# 16 Test CV Score    0.9340

# %%
metrics_df = pd.DataFrame(metrics).T
cols = {'02 Test score': 'Accuracy scores', 
        '10 False Positives': 'ROC AUC scores', 
        '14 Test ROC Score': 'False Positives count', 
        '06 Precision': 'Precision'}

for col in cols.keys():
    metrics_df[col] = metrics_df[col].astype('float')
    sns.barplot(x=metrics_df.index, y=col, data=metrics_df, ci=None);
    plt.title(cols[col])
    plt.show();

# %%
# Combine chart of ROC/AUC
fig, ax = plt.subplots(figsize=(12,12));
lr_plot = plot_roc_curve(models['log_reg'].best_estimator_, X_test, y_test, name='Logistic Regression',ax=ax);
knn_plot = plot_roc_curve(models['k_neighbor'].best_estimator_, X_test, y_test, name='KNeighborsClassifier',ax=ax);
rf_plot = plot_roc_curve(models['random_forest'].best_estimator_, X_test, y_test, name='Random Forest', ax=ax);
et_plot = plot_roc_curve(models['extra_trees'].best_estimator_, X_test, y_test, name='Extra Trees', ax=ax);
gb_plot = plot_roc_curve(models['gboost'].best_estimator_, X_test, y_test, name='Gradient Boosting', ax=ax);
ada_plot = plot_roc_curve(models['ada'].best_estimator_, X_test, y_test, name='AdaBoost', ax=ax);
plt.plot(np.linspace(0, 1, 200), np.linspace(0, 1, 200), label='baseline', linestyle='--');

# %% [markdown]
# ### Model Selection and Feature Importance

# %% [markdown]
# #### Interpreting Gradient Boosting

# %%
gboost = GradientBoostingClassifier(max_depth=3, min_samples_leaf=2, min_samples_split=2, n_estimators=150, random_state=42)
gboost.fit(X_train, y_train)
# Out:
# GradientBoostingClassifier(min_samples_leaf=2, n_estimators=150,
#                            random_state=42)

# %%
imp_gboost = pd.DataFrame(gboost.feature_importances_,
                       index=X.columns,
                       columns=['weights']).sort_values(by='weights', ascending=False)

# %%
# Plot in bar chart
imp_gboost.head(20).plot(kind='barh', label=imp_gboost.columns[:20], figsize=(12,7), color='green')
plt.title('Top 20 Feature Importance for Gradient Boost', fontsize=15)
plt.gca().invert_yaxis()
plt.legend(loc=4);

# %% [markdown]
# #### Interpreting Logistic Regression

# %%
lr = LogisticRegression(random_state=42, max_iter=5000, C=0.1)
lr.fit(X_train, y_train)
# Out:
# LogisticRegression(C=0.1, max_iter=5000, random_state=42)

# %%
lr.coef_.shape
# Out:
# (1, 219)

# %%
importance = lr.coef_
features = X_train.columns
importance = importance.reshape(lr.coef_.shape[1],1)
imp_lr = pd.DataFrame(importance,
                       index=features,
                       columns=['weights']).sort_values(by='weights', ascending=False)
imp_lr
# Out:
#                                  weights
# Cool                            1.139563
# PrecipTotal_lag_3               1.001277
# StnPressure_lag_3               0.987428
# Longitude                       0.969322
# PrecipTotal_lag_14              0.954315
# ...                                  ...
# Trap_T138                      -1.899862
# Species_CULEX RESTUANS         -2.919002
# Species_CULEX PIPIENS/RESTUANS -2.998254
# Species_CULEX PIPIENS          -3.160528
# Species_CULEX TERRITANS        -3.232334
#
# [219 rows x 1 columns]

# %%
# Plotting top 20 +ve features in bar chart
imp_lr['weights'].head(20).plot(kind='barh', figsize=(12,7))
plt.title('Top 20 Feature Coefficients (+ve) for Logistic Regression', fontsize=15)
plt.gca().invert_yaxis()
plt.legend(loc=4);

# %%
# Plotting top 20 -ve features in bar chart
imp_lr['weights'].tail(20).plot(kind='barh', figsize=(12,7))
plt.title('Top 20 Feature Coefficients (-ve) for Logistic Regression', fontsize=15)
plt.legend(loc=3);

# %%
xxx
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [64], in <cell line: 1>()
# ----> 1 xxx
#
# NameError: name 'xxx' is not defined

# %% [markdown]
# ### Polynomial Feature Engineering

# %%
# generate the polynomial features, with degree of 2
poly = PolynomialFeatures(include_bias=False, degree=2)

# transform the features
X_poly = poly.fit_transform(X)

# view the shape
print('Our train data with polynomial features included has {} rows and {} columns.'.format(X_poly.shape[0],
                                                                                            X_poly.shape[1]))

# %%
# obtain the features' names
X_poly = pd.DataFrame(X_poly, columns=poly.get_feature_names(X.columns))

# generate list of poly feature correlation with y
X_poly_corrs = X_poly.corrwith(y)

# %%
# show features that are most highly correlated (positively) with target
X_poly_corrs_ab = abs(X_poly_corrs)
X_poly_corrs_ab.sort_values(ascending=False).head(20)
